# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla K80'

# %%
# !/opt/bin/nvidia-smi
# Out:
# Fri Jul 17 06:34:40 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    34W / 149W |     11MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/internship/ERFNet-CULane-PyTorch')

# %%
# %cd /content/drive/My\ Drive/internship/ERFNet-CULane-PyTorch
# Out:
# /content/drive/My Drive/internship/ERFNet-CULane-PyTorch

# %%
# !python3 -u test_erfnet.py --dataset='CULane' \
               --method='ERFNet' \
               --val_list='test' \
               --lr=0.01 \
               --gpus=0 \
               --resume='/content/drive/My Drive/internship/ERFNet-CULane-PyTorch/trained/_erfnet_model_best.pth.tar' \
               --img_height=480 \
               --img_width=480 \
               -j=12 \
               -b=12 \
               --outdir='predicts/600_fullset_warmup'
# Out:
# => loading checkpoint '/content/drive/My Drive/internship/ERFNet-CULane-PyTorch/trained/_erfnet_model_best.pth.tar'
# => loaded checkpoint 'False' (epoch 548)
# group: addtional weight has 0 params, lr_mult: 10, decay_mult: 1
# group: addtional bias has 0 params, lr_mult: 20, decay_mult: 1
# group: addtional BN scale/shift has 0 params, lr_mult: 10, decay_mult: 0
# group: base weight has 72 params, lr_mult: 1, decay_mult: 1
# group: base bias has 72 params, lr_mult: 2, decay_mult: 0
# group: base BN scale/shift has 78 params, lr_mult: 1, decay_mult: 0
# test_erfnet.py:109: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input_var = torch.autograd.Variable(input, volatile=True)
# Test: [0/5]	Time 2.045 (2.045)
# Test: [1/5]	Time 0.801 (1.423)
# Test: [2/5]	Time 0.806 (1.217)
# Test: [3/5]	Time 0.876 (1.132)
# Test: [4/5]	Time 0.429 (0.991)
# Testing Results: Pixels Acc 0.955	mIoU 0.417 (0.4171)

# %%
# !python3 -u train_erfnet.py --dataset='CULane' \
               --method='ERFNet' \
               --train_list='train' \
               --val_list='val' \
               --lr=0.01 \
               --gpus=0 \
               --resume='' \
               --img_height=480 \
               --img_width=480 \
               --epochs=300 \
               -j=12 \
               -b=12
# Out:
# => loading checkpoint '/content/drive/My Drive/internship/ERFNet-CULane-PyTorch/trained/_erfnet_model_best.pth.tar'
# #reused param: 353
# => loaded checkpoint 'False' (epoch 496)
# Traceback (most recent call last):
#   File "train_erfnet.py", line 314, in <module>
#     main()
#   File "train_erfnet.py", line 121, in main
#     train(train_loader, model, criterion, criterion_exist, optimizer, epoch)
#   File "train_erfnet.py", line 156, in train
#     for i, (input, target) in enumerate(train_loader):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 345, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 856, in _next_data
#     return self._process_data(data)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 881, in _process_data
#     data.reraise()
# ...

# %%
# !python3 -u train_erfnet.py --dataset='CULane' \
               --method='ERFNet' \
               --train_list='train' \
               --val_list='val' \
               --lr=0.01 \
               --gpus=0 \
               --resume='/content/drive/My Drive/internship/ERFNet-CULane-PyTorch/trained/_erfnet_final.path.tar' \
               --img_height=480 \
               --img_width=480 \
               --epochs=600 \
               -j=12 \
               -b=12
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Epoch: [443][25/26], lr: 0.00299	Time 0.139 (0.139)	Data 0.003 (0.003)	Loss 0.0388 (0.0388)
# Test: [0/5]	Time 1.445 (1.445)	Loss -0.9094 (-0.9094)	Pixels Acc 0.981	mIoU 0.377
# Test: [1/5]	Time 0.227 (0.836)	Loss -0.8458 (-0.8776)	Pixels Acc 0.978	mIoU 0.342
# Test: [2/5]	Time 0.224 (0.632)	Loss -0.8645 (-0.8732)	Pixels Acc 0.978	mIoU 0.390
# Test: [3/5]	Time 0.225 (0.530)	Loss -0.8285 (-0.8621)	Pixels Acc 0.975	mIoU 0.379
# Test: [4/5]	Time 0.060 (0.436)	Loss -0.7559 (-0.8578)	Pixels Acc 0.975	mIoU 0.375
# Testing Results: Pixels Acc 0.975	mIoU 0.375 (0.3796)	Loss -0.85780
# Epoch: [444][0/26], lr: 0.00297	Time 3.328 (3.328)	Data 2.714 (2.714)	Loss 0.0346 (0.0346)
# Epoch: [444][1/26], lr: 0.00297	Time 0.501 (0.501)	Data 0.094 (0.094)	Loss 0.0291 (0.0291)
# Epoch: [444][2/26], lr: 0.00297	Time 0.395 (0.395)	Data 0.003 (0.003)	Loss 0.0255 (0.0255)
# Epoch: [444][3/26], lr: 0.00297	Time 0.504 (0.504)	Data 0.018 (0.018)	Loss 0.0258 (0.0258)
# ...
